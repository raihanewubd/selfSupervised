# %% [markdown]
# <a href="https://colab.research.google.com/github/raihanewubd/selfSupervised/blob/main/AAV_SelfSupervised_06_GoogleNet_2_layer_hidden_projection_head_earlystopping_VICReg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Using fine tuned GoogleNet

# %%
import torch
import torch.nn as nn

import torch.nn.functional as F
import torch.optim as optim

import torchvision
import torchvision.transforms as T
import torchvision.transforms as transforms
import torchvision.models as models
import torchvision.datasets as datasets
from torch.utils.data import DataLoader, Dataset, random_split, Subset
import numpy as np
from PIL import Image
from google.colab import drive
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

import os
import zipfile
import glob
import shutil
from collections import Counter
from scipy import stats
from collections import Counter

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Define dataset path
zip_path = "/content/drive/MyDrive/AAVDATASET/100mV1s_segment_raw.zip"
extract_path = "/content/dataset/"
data_dir = '/content/dataset/train_val_photos'
# Unzip dataset
if not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

# %%
data_dir = '/content/dataset/train_val_photos'
checkpoint_dir = os.path.join(data_dir, '.ipynb_checkpoints')
if os.path.exists(checkpoint_dir):
    shutil.rmtree(checkpoint_dir)

# %%
# Valid image extensions.
valid_extensions = ('.jpg', '.jpeg', '.png', '.ppm', '.bmp', '.pgm', '.tif', '.tiff', '.webp')

def is_valid_file(file_path):
    """Filters out hidden files and directories."""
    base_name = os.path.basename(file_path)
    if base_name.startswith('.'):  # Check for hidden files and directories
        return False
    return file_path.lower().endswith(valid_extensions)

# Dictionary to store subfolder name and file count
file_counts = {}

# Get the list of subdirectories (classes)
classes = os.listdir(data_dir)

for class_name in classes:
    class_path = os.path.join(data_dir, class_name)
    if os.path.isdir(class_path): # Ensure it's a directory
        # Count files in the subdirectory, filtering for valid files
        count = sum(1 for entry in os.listdir(class_path) if os.path.isfile(os.path.join(class_path, entry)) and is_valid_file(os.path.join(class_path, entry)))
        file_counts[class_name] = count

# Print the file counts
total = 0
for class_name, count in file_counts.items():
    total += count
    print(f"Subfolder '{class_name}': {count} files")
print(f"Total files: {total}")
# Out:
# Subfolder 'Double': 1028 files
# Subfolder 'Single': 1088 files
# Subfolder 'Empty': 616 files
# Total files: 2732

# %% [markdown]
# # Pre Training Task

# %%
import os
import time
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, Subset
from torchvision import datasets, transforms, models
import torchvision.transforms as T
from torch.cuda.amp import GradScaler, autocast
import torch.nn.functional as F
import numpy as np
import pandas as pd
from PIL import Image
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.mixture import GaussianMixture
import umap
from scipy.optimize import linear_sum_assignment
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Configuration
DATA_ROOT = "/content/dataset/train_val_photos"
BATCH_SIZE = 256
NUM_WORKERS = 8
LR = 5e-4
EPOCHS = 3000
LAMBDA_INV = 25.0  # VICReg invariance weight
LAMBDA_VAR = 25.0  # VICReg variance weight
LAMBDA_COV = 1.0   # VICReg covariance weight
PROJ_DIM = 256
PATIENCE = 100
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
MODEL_PATH = f"/content/drive/MyDrive/AAVDATASET/models/googlenet_vicreg__lr{LR:.4f}_inv{LAMBDA_INV:.1f}_var{LAMBDA_VAR:.1f}_cov{LAMBDA_COV:.1f}_e{EPOCHS}_b{BATCH_SIZE}_pd{PROJ_DIM}.pth"
FINAL_MODEL_PATH = MODEL_PATH.replace('.pth', '_final.pth')
INDICES_PATH = '/content/drive/MyDrive/AAVDATASET/models/dataset_indices.xlsx'

torch.backends.cudnn.benchmark = True
torch.cuda.empty_cache()

# SimCLR augmentations (used for VICReg)
simclr_transform = T.Compose([
    T.RandomResizedCrop(224, scale=(0.2, 1.0)),
    T.RandomHorizontalFlip(p=0.5),
    T.ColorJitter(0.8, 0.8, 0.8, 0.2),
    T.RandomGrayscale(p=0.2),
    T.RandomRotation(15),
    T.ToTensor(),
    T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Evaluation transform
eval_transform = T.Compose([
    T.Resize(224),
    T.CenterCrop(224),
    T.ToTensor(),
    T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Load dataset and split
full_dataset = datasets.ImageFolder(DATA_ROOT)
full_samples = full_dataset.samples
n = len(full_samples)
train_len = int(0.8 * n)
val_len = int(0.1 * n)
test_len = n - train_len - val_len

generator = torch.Generator().manual_seed(42)
perm = torch.randperm(n, generator=generator).tolist()
train_idxs = perm[:train_len]
val_idxs = perm[train_len:train_len + val_len]
test_idxs = perm[train_len + val_len:]

# Save indices
pd.DataFrame({
    'Train_Indices': pd.Series(train_idxs),
    'Val_Indices': pd.Series(val_idxs),
    'Test_Indices': pd.Series(test_idxs)
}).to_excel(INDICES_PATH, index=False)

train_samples = [full_samples[i] for i in train_idxs]
val_samples = [full_samples[i] for i in val_idxs]
test_samples = [full_samples[i] for i in test_idxs]

# SimCLR Dataset (used for VICReg)
class SimCLRDataset(Dataset):
    def __init__(self, samples_list, transform):
        self.samples = samples_list
        self.transform = transform

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        path, _ = self.samples[idx]
        img = Image.open(path).convert("RGB")
        x1 = self.transform(img)
        x2 = self.transform(img)
        return x1, x2

# Data loaders
ssl_train_ds = SimCLRDataset(train_samples, simclr_transform)
pretrain_loader = DataLoader(
    ssl_train_ds, batch_size=BATCH_SIZE, shuffle=True,
    num_workers=NUM_WORKERS, pin_memory=True, drop_last=True,
    persistent_workers=True, prefetch_factor=2
)

eval_full_ds = datasets.ImageFolder(DATA_ROOT, transform=eval_transform)
train_eval_ds = Subset(eval_full_ds, train_idxs)
val_eval_ds = Subset(eval_full_ds, val_idxs)
test_eval_ds = Subset(eval_full_ds, test_idxs)

train_loader = DataLoader(
    train_eval_ds, batch_size=BATCH_SIZE, shuffle=True,
    num_workers=NUM_WORKERS, pin_memory=True, persistent_workers=True, prefetch_factor=2
)
val_loader = DataLoader(
    val_eval_ds, batch_size=BATCH_SIZE, shuffle=False,
    num_workers=NUM_WORKERS, pin_memory=True, persistent_workers=True, prefetch_factor=2
)
test_loader = DataLoader(
    test_eval_ds, batch_size=BATCH_SIZE, shuffle=False,
    num_workers=NUM_WORKERS, pin_memory=True, persistent_workers=True, prefetch_factor=2
)

# VICReg loss
def vicreg_loss(z1, z2, lambda_inv=25, lambda_var=25, lambda_cov=1):
    # Invariance term (MSE loss)
    inv_loss = F.mse_loss(z1, z2)

    # Variance term
    z1_std = torch.sqrt(z1.var(dim=0) + 1e-4)
    z2_std = torch.sqrt(z2.var(dim=0) + 1e-4)
    var_loss = torch.mean(F.relu(1 - z1_std)) + torch.mean(F.relu(1 - z2_std))

    # Covariance term
    z1 = z1 - z1.mean(dim=0)
    z2 = z2 - z2.mean(dim=0)
    cov1 = (z1.T @ z1) / (z1.size(0) - 1)
    cov2 = (z2.T @ z2) / (z2.size(0) - 1)
    cov_loss = cov1.triu(diagonal=1).pow(2).sum() + cov2.triu(diagonal=1).pow(2).sum()

    return lambda_inv * inv_loss + lambda_var * var_loss + lambda_cov * cov_loss

# Model setup
backbone = models.googlenet(pretrained=True, aux_logits=True)
backbone.aux_logits = False
backbone.aux1 = None
backbone.aux2 = None
feat_dim = backbone.fc.in_features
backbone.fc = nn.Identity()
backbone = backbone.to(DEVICE)

projection_head = nn.Sequential(
    nn.Linear(feat_dim, feat_dim, bias=False),
    nn.BatchNorm1d(feat_dim),
    nn.ReLU(inplace=True),
    nn.Linear(feat_dim, feat_dim, bias=False),
    nn.BatchNorm1d(feat_dim),
    nn.ReLU(inplace=True),
    nn.Linear(feat_dim, PROJ_DIM, bias=True)
).to(DEVICE)

if hasattr(torch, 'compile'):
    backbone = torch.compile(backbone)
    projection_head = torch.compile(projection_head)

optimizer = optim.Adam(
    list(backbone.parameters()) + list(projection_head.parameters()), lr=LR
)
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS)
scaler = GradScaler()

num_classes = len(eval_full_ds.classes)
classifier = nn.Linear(feat_dim, num_classes).to(DEVICE)
clf_optimizer = optim.Adam(classifier.parameters(), lr=1e-3)

# Training loop with early stopping
best_loss = float('inf')
best_val_acc = 0.0
patience_counter = 0

for epoch in range(1, EPOCHS + 1):
    backbone.train()
    projection_head.train()
    total_loss = 0.0
    start = time.time()

    for x1, x2 in pretrain_loader:
        x1 = x1.to(DEVICE, non_blocking=True)
        x2 = x2.to(DEVICE, non_blocking=True)
        optimizer.zero_grad()
        with autocast():
            z1 = projection_head(backbone(x1))
            z2 = projection_head(backbone(x2))
            loss = vicreg_loss(z1, z2, LAMBDA_INV, LAMBDA_VAR, LAMBDA_COV)
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        total_loss += loss.item()

    scheduler.step()

    avg_loss = total_loss / len(pretrain_loader)
    if avg_loss < best_loss:
        best_loss = avg_loss
        torch.save(backbone.state_dict(), MODEL_PATH)
        s = f" Saved new best backbone (loss {best_loss:.4f})"
    else:
        s = ""

    # Linear evaluation
    backbone.eval()
    classifier.train()
    for imgs, labels in train_loader:
        imgs = imgs.to(DEVICE, non_blocking=True)
        labels = labels.to(DEVICE, non_blocking=True)
        logits = classifier(backbone(imgs))
        loss = F.cross_entropy(logits, labels)
        clf_optimizer.zero_grad()
        loss.backward()
        clf_optimizer.step()

    # Validation
    classifier.eval()
    correct = total = 0
    with torch.no_grad():
        for imgs, labels in val_loader:
            imgs = imgs.to(DEVICE, non_blocking=True)
            labels = labels.to(DEVICE, non_blocking=True)
            preds = classifier(backbone(imgs)).argmax(1)
            total += labels.size(0)
            correct += (preds == labels).sum().item()
    val_acc = correct / total

    # Early stopping check
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        patience_counter = 0
        torch.save({
            'backbone_state_dict': backbone.state_dict(),
            'classifier_state_dict': classifier.state_dict(),
        }, MODEL_PATH.replace('.pth', '_best_val.pth'))
        s += f" Saved best val model (acc {best_val_acc:.4f})"
    else:
        patience_counter += 1

    print(f"Epoch {epoch}/{EPOCHS} — Loss: {avg_loss:.4f} — Val Acc: {val_acc:.4f} — Time: {time.time()-start:.1f}s {s}")

    if patience_counter >= PATIENCE:
        print(f"Early stopping triggered after {epoch} epochs (no improvement in val_acc for {PATIENCE} epochs)")
        break

# Save final model
torch.save(backbone.state_dict(), FINAL_MODEL_PATH)
print(f"Saved final pretrained encoder to {FINAL_MODEL_PATH}")

# Clustering evaluation
backbone.load_state_dict(torch.load(MODEL_PATH, map_location=DEVICE))
backbone = backbone.to(DEVICE).eval()

# Feature extraction
features, labels = [], []
with torch.no_grad():
    for imgs, labs in test_loader:
        feats = backbone(imgs.to(DEVICE)).cpu().numpy()
        features.append(feats)
        labels.append(labs.numpy())

X = np.concatenate(features, axis=0)
y = np.concatenate(labels, axis=0)
class_names = eval_full_ds.classes
print(f"Feature dimension: {X.shape[1]}")

# 2D projection via UMAP
X_2d = umap.UMAP(n_components=2, random_state=42).fit_transform(X)

# True labels visualization
plt.figure(figsize=(6, 6))
plt.scatter(X_2d[:, 0], X_2d[:, 1], c=y, s=5, cmap='tab10')
plt.title("True Labels")
plt.xlabel("UMAP Component 1")
plt.ylabel("UMAP Component 2")
plt.show()

# Clustering algorithms
algorithms = {
    "KMeans": KMeans(n_clusters=num_classes, init='k-means++', random_state=42),
    "Agglomerative": AgglomerativeClustering(n_clusters=num_classes),
    "GMM": GaussianMixture(n_components=num_classes, covariance_type='full', random_state=42)
}

# Utility: accuracy and mapping
def cluster_accuracy(y_true, y_pred):
    D = max(y_pred.max(), y_true.max()) + 1
    contingency = np.zeros((D, D), dtype=int)
    for i in range(len(y_true)):
        contingency[y_pred[i], y_true[i]] += 1
    row_ind, col_ind = linear_sum_assignment(-contingency)
    accuracy = contingency[row_ind, col_ind].sum() / y_true.size
    return accuracy, dict(zip(row_ind, col_ind))

# Evaluate & visualize
for name, algo in algorithms.items():
    if name == "GMM":
        y_pred = algo.fit_predict(X)
    else:
        y_pred = algo.fit(X).labels_

    acc, mapping = cluster_accuracy(y, y_pred)
    y_mapped = np.vectorize(mapping.get)(y_pred)

    rows = []
    for idx, cls in enumerate(class_names):
        mask = (y == idx)
        correct = (y_mapped[mask] == idx).sum()
        total = mask.sum()
        rows.append({"Class": cls, "Correct": correct, "Incorrect": total - correct})
    df = pd.DataFrame(rows).set_index("Class")
    print(f"{name} per-class results\n{df}\n")

    plt.figure(figsize=(6, 6))
    plt.scatter(X_2d[:, 0], X_2d[:, 1], c=y_pred, s=5, cmap='tab10')
    plt.title(f"{name} clusters (ACC={acc:.4f})")
    plt.xlabel("UMAP Component 1")
    plt.ylabel("UMAP Component 2")
    plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=GoogLeNet_Weights.IMAGENET1K_V1`. You can also use `weights=GoogLeNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /usr/local/lib/python3.11/dist-packages/torchvision/models/googlenet.py:341: UserWarning: auxiliary heads in the pretrained googlenet model are NOT pretrained, so make sure to train them
#   warnings.warn(
# <ipython-input-6-e18b9179d99f>:173: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# <ipython-input-6-e18b9179d99f>:194: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# <ipython-input-6-e18b9179d99f>:194: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 1/3000 — Loss: 45.0290 — Val Acc: 0.6264 — Time: 105.5s  Saved new best backbone (loss 45.0290) Saved best val model (acc 0.6264)
# <ipython-input-6-e18b9179d99f>:194: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 2/3000 — Loss: 42.4902 — Val Acc: 0.7399 — Time: 21.9s  Saved new best backbone (loss 42.4902) Saved best val model (acc 0.7399)
# Epoch 3/3000 — Loss: 41.9184 — Val Acc: 0.7253 — Time: 17.3s  Saved new best backbone (loss 41.9184)
# Epoch 4/3000 — Loss: 41.8184 — Val Acc: 0.7436 — Time: 18.0s  Saved new best backbone (loss 41.8184) Saved best val model (acc 0.7436)
# Epoch 5/3000 — Loss: 41.7576 — Val Acc: 0.7546 — Time: 17.5s  Saved new best backbone (loss 41.7576) Saved best val model (acc 0.7546)
# Epoch 6/3000 — Loss: 41.7134 — Val Acc: 0.7363 — Time: 17.1s  Saved new best backbone (loss 41.7134)
# Epoch 7/3000 — Loss: 41.6819 — Val Acc: 0.7875 — Time: 17.9s  Saved new best backbone (loss 41.6819) Saved best val model (acc 0.7875)
# Epoch 8/3000 — Loss: 41.6531 — Val Acc: 0.7985 — Time: 16.6s  Saved new best backbone (loss 41.6531) Saved best val model (acc 0.7985)
# Epoch 9/3000 — Loss: 41.6500 — Val Acc: 0.7766 — Time: 17.5s  Saved new best backbone (loss 41.6500)
# Epoch 10/3000 — Loss: 41.6235 — Val Acc: 0.8095 — Time: 17.4s  Saved new best backbone (loss 41.6235) Saved best val model (acc 0.8095)
# Epoch 11/3000 — Loss: 41.6179 — Val Acc: 0.7399 — Time: 17.7s  Saved new best backbone (loss 41.6179)
# Epoch 12/3000 — Loss: 41.6068 — Val Acc: 0.7216 — Time: 17.9s  Saved new best backbone (loss 41.6068)
# Epoch 13/3000 — Loss: 41.6062 — Val Acc: 0.7802 — Time: 17.4s  Saved new best backbone (loss 41.6062)
# Epoch 14/3000 — Loss: 41.5998 — Val Acc: 0.7875 — Time: 17.3s  Saved new best backbone (loss 41.5998)
# Epoch 15/3000 — Loss: 41.5922 — Val Acc: 0.8205 — Time: 17.8s  Saved new best backbone (loss 41.5922) Saved best val model (acc 0.8205)
# Epoch 16/3000 — Loss: 41.5904 — Val Acc: 0.8205 — Time: 17.7s  Saved new best backbone (loss 41.5904)
# Epoch 17/3000 — Loss: 41.5834 — Val Acc: 0.8168 — Time: 17.8s  Saved new best backbone (loss 41.5834)
# Epoch 18/3000 — Loss: 41.5788 — Val Acc: 0.8278 — Time: 17.9s  Saved new best backbone (loss 41.5788) Saved best val model (acc 0.8278)
# Epoch 19/3000 — Loss: 41.5659 — Val Acc: 0.8022 — Time: 17.4s  Saved new best backbone (loss 41.5659)
# Epoch 20/3000 — Loss: 41.5628 — Val Acc: 0.8205 — Time: 17.3s  Saved new best backbone (loss 41.5628)
# Epoch 21/3000 — Loss: 41.5933 — Val Acc: 0.8168 — Time: 18.0s
# Epoch 22/3000 — Loss: 41.5756 — Val Acc: 0.8059 — Time: 17.3s
# Epoch 23/3000 — Loss: 41.5844 — Val Acc: 0.7949 — Time: 16.6s
# Epoch 24/3000 — Loss: 41.5693 — Val Acc: 0.8168 — Time: 16.8s
# Epoch 25/3000 — Loss: 41.5770 — Val Acc: 0.8242 — Time: 16.9s
# Epoch 26/3000 — Loss: 41.5594 — Val Acc: 0.8315 — Time: 17.4s  Saved new best backbone (loss 41.5594) Saved best val model (acc 0.8315)
# Epoch 27/3000 — Loss: 41.5524 — Val Acc: 0.8168 — Time: 17.3s  Saved new best backbone (loss 41.5524)
# Epoch 28/3000 — Loss: 41.5528 — Val Acc: 0.8388 — Time: 17.0s  Saved best val model (acc 0.8388)
# Epoch 29/3000 — Loss: 41.5450 — Val Acc: 0.8095 — Time: 17.9s  Saved new best backbone (loss 41.5450)
# Epoch 30/3000 — Loss: 41.5263 — Val Acc: 0.7949 — Time: 17.2s  Saved new best backbone (loss 41.5263)
# Epoch 31/3000 — Loss: 41.5348 — Val Acc: 0.7875 — Time: 16.8s
# Epoch 32/3000 — Loss: 41.5221 — Val Acc: 0.7729 — Time: 18.0s  Saved new best backbone (loss 41.5221)
# Epoch 33/3000 — Loss: 41.5008 — Val Acc: 0.8352 — Time: 18.2s  Saved new best backbone (loss 41.5008)
# Epoch 34/3000 — Loss: 41.4934 — Val Acc: 0.8022 — Time: 17.7s  Saved new best backbone (loss 41.4934)
# Epoch 35/3000 — Loss: 41.4753 — Val Acc: 0.8059 — Time: 17.8s  Saved new best backbone (loss 41.4753)
# Epoch 36/3000 — Loss: 41.4863 — Val Acc: 0.7729 — Time: 17.4s
# Epoch 37/3000 — Loss: 41.4818 — Val Acc: 0.7949 — Time: 17.9s
# Epoch 38/3000 — Loss: 41.4612 — Val Acc: 0.8205 — Time: 17.0s  Saved new best backbone (loss 41.4612)
# Epoch 39/3000 — Loss: 41.4441 — Val Acc: 0.7802 — Time: 17.9s  Saved new best backbone (loss 41.4441)
# Epoch 40/3000 — Loss: 41.4364 — Val Acc: 0.8462 — Time: 18.0s  Saved new best backbone (loss 41.4364) Saved best val model (acc 0.8462)
# Epoch 41/3000 — Loss: 41.4148 — Val Acc: 0.8462 — Time: 16.5s  Saved new best backbone (loss 41.4148)
# Epoch 42/3000 — Loss: 41.3635 — Val Acc: 0.7985 — Time: 18.2s  Saved new best backbone (loss 41.3635)
# Epoch 43/3000 — Loss: 41.3593 — Val Acc: 0.8425 — Time: 17.6s  Saved new best backbone (loss 41.3593)
# Epoch 44/3000 — Loss: 41.3543 — Val Acc: 0.8535 — Time: 17.2s  Saved new best backbone (loss 41.3543) Saved best val model (acc 0.8535)
# Epoch 45/3000 — Loss: 41.3408 — Val Acc: 0.8278 — Time: 17.3s  Saved new best backbone (loss 41.3408)
# Epoch 46/3000 — Loss: 41.3206 — Val Acc: 0.8571 — Time: 17.7s  Saved new best backbone (loss 41.3206) Saved best val model (acc 0.8571)
# Epoch 47/3000 — Loss: 41.3270 — Val Acc: 0.8278 — Time: 17.4s
# Epoch 48/3000 — Loss: 41.2674 — Val Acc: 0.8645 — Time: 17.6s  Saved new best backbone (loss 41.2674) Saved best val model (acc 0.8645)
# Epoch 49/3000 — Loss: 41.2554 — Val Acc: 0.8352 — Time: 17.6s  Saved new best backbone (loss 41.2554)
# Epoch 50/3000 — Loss: 41.2464 — Val Acc: 0.8535 — Time: 16.5s  Saved new best backbone (loss 41.2464)
# Epoch 51/3000 — Loss: 41.2329 — Val Acc: 0.8571 — Time: 17.5s  Saved new best backbone (loss 41.2329)
# Epoch 52/3000 — Loss: 41.1990 — Val Acc: 0.8608 — Time: 17.7s  Saved new best backbone (loss 41.1990)
# Epoch 53/3000 — Loss: 41.1831 — Val Acc: 0.8718 — Time: 17.7s  Saved new best backbone (loss 41.1831) Saved best val model (acc 0.8718)
# Epoch 54/3000 — Loss: 41.1618 — Val Acc: 0.8645 — Time: 17.8s  Saved new best backbone (loss 41.1618)
# Epoch 55/3000 — Loss: 41.1273 — Val Acc: 0.8608 — Time: 17.1s  Saved new best backbone (loss 41.1273)
# Epoch 56/3000 — Loss: 41.1082 — Val Acc: 0.8755 — Time: 17.2s  Saved new best backbone (loss 41.1082) Saved best val model (acc 0.8755)
# Epoch 57/3000 — Loss: 41.0756 — Val Acc: 0.8938 — Time: 16.6s  Saved new best backbone (loss 41.0756) Saved best val model (acc 0.8938)
# Epoch 58/3000 — Loss: 41.0646 — Val Acc: 0.8462 — Time: 17.4s  Saved new best backbone (loss 41.0646)
# Epoch 59/3000 — Loss: 41.0266 — Val Acc: 0.8681 — Time: 17.2s  Saved new best backbone (loss 41.0266)
# Epoch 60/3000 — Loss: 40.9583 — Val Acc: 0.8791 — Time: 17.5s  Saved new best backbone (loss 40.9583)
# Epoch 61/3000 — Loss: 40.9653 — Val Acc: 0.8828 — Time: 16.8s
# Epoch 62/3000 — Loss: 40.9334 — Val Acc: 0.8864 — Time: 17.8s  Saved new best backbone (loss 40.9334)
# Epoch 63/3000 — Loss: 40.9503 — Val Acc: 0.8828 — Time: 17.5s
# Epoch 64/3000 — Loss: 40.8847 — Val Acc: 0.8901 — Time: 16.7s  Saved new best backbone (loss 40.8847)
# Epoch 65/3000 — Loss: 40.8879 — Val Acc: 0.8828 — Time: 17.7s
# Epoch 66/3000 — Loss: 40.8473 — Val Acc: 0.8718 — Time: 17.4s  Saved new best backbone (loss 40.8473)
# Epoch 67/3000 — Loss: 40.8196 — Val Acc: 0.8718 — Time: 16.6s  Saved new best backbone (loss 40.8196)
# Epoch 68/3000 — Loss: 40.8116 — Val Acc: 0.8864 — Time: 17.5s  Saved new best backbone (loss 40.8116)
# Epoch 69/3000 — Loss: 40.7543 — Val Acc: 0.8791 — Time: 16.7s  Saved new best backbone (loss 40.7543)
# Epoch 70/3000 — Loss: 40.7620 — Val Acc: 0.8571 — Time: 17.3s
# Epoch 71/3000 — Loss: 40.6997 — Val Acc: 0.8938 — Time: 17.7s  Saved new best backbone (loss 40.6997)
# Epoch 72/3000 — Loss: 40.7008 — Val Acc: 0.8938 — Time: 17.3s
# Epoch 73/3000 — Loss: 40.6895 — Val Acc: 0.8828 — Time: 17.2s  Saved new best backbone (loss 40.6895)
# Epoch 74/3000 — Loss: 40.6460 — Val Acc: 0.8755 — Time: 17.7s  Saved new best backbone (loss 40.6460)
# Epoch 75/3000 — Loss: 40.5749 — Val Acc: 0.8901 — Time: 17.3s  Saved new best backbone (loss 40.5749)
# Epoch 76/3000 — Loss: 40.6119 — Val Acc: 0.8645 — Time: 17.6s
# Epoch 77/3000 — Loss: 40.5515 — Val Acc: 0.8938 — Time: 16.4s  Saved new best backbone (loss 40.5515)
# Epoch 78/3000 — Loss: 40.4772 — Val Acc: 0.8791 — Time: 15.3s  Saved new best backbone (loss 40.4772)
# Epoch 79/3000 — Loss: 40.4959 — Val Acc: 0.8974 — Time: 17.7s  Saved best val model (acc 0.8974)
# Epoch 80/3000 — Loss: 40.4718 — Val Acc: 0.8938 — Time: 17.1s  Saved new best backbone (loss 40.4718)
# Epoch 81/3000 — Loss: 40.3904 — Val Acc: 0.8901 — Time: 16.3s  Saved new best backbone (loss 40.3904)
# Epoch 82/3000 — Loss: 40.4233 — Val Acc: 0.8864 — Time: 17.8s
# Epoch 83/3000 — Loss: 40.4120 — Val Acc: 0.9084 — Time: 17.0s  Saved best val model (acc 0.9084)
# Epoch 84/3000 — Loss: 40.4045 — Val Acc: 0.8938 — Time: 15.9s
# Epoch 85/3000 — Loss: 40.3473 — Val Acc: 0.9048 — Time: 17.3s  Saved new best backbone (loss 40.3473)
# Epoch 86/3000 — Loss: 40.3009 — Val Acc: 0.9084 — Time: 17.1s  Saved new best backbone (loss 40.3009)
# Epoch 87/3000 — Loss: 40.2731 — Val Acc: 0.8755 — Time: 17.5s  Saved new best backbone (loss 40.2731)
# Epoch 88/3000 — Loss: 40.3129 — Val Acc: 0.8901 — Time: 16.6s
# Epoch 89/3000 — Loss: 40.2584 — Val Acc: 0.8901 — Time: 17.5s  Saved new best backbone (loss 40.2584)
# Epoch 90/3000 — Loss: 40.3111 — Val Acc: 0.8681 — Time: 17.0s
# Epoch 91/3000 — Loss: 40.2545 — Val Acc: 0.8864 — Time: 16.8s  Saved new best backbone (loss 40.2545)
# Epoch 92/3000 — Loss: 40.1902 — Val Acc: 0.9048 — Time: 17.8s  Saved new best backbone (loss 40.1902)
# Epoch 93/3000 — Loss: 40.2076 — Val Acc: 0.8864 — Time: 17.9s
# Epoch 94/3000 — Loss: 40.1653 — Val Acc: 0.8864 — Time: 17.1s  Saved new best backbone (loss 40.1653)
# Epoch 95/3000 — Loss: 40.1511 — Val Acc: 0.9048 — Time: 17.8s  Saved new best backbone (loss 40.1511)
# Epoch 96/3000 — Loss: 40.0917 — Val Acc: 0.9048 — Time: 17.6s  Saved new best backbone (loss 40.0917)
# Epoch 97/3000 — Loss: 40.0656 — Val Acc: 0.8864 — Time: 17.1s  Saved new best backbone (loss 40.0656)
# Epoch 98/3000 — Loss: 40.0477 — Val Acc: 0.8938 — Time: 16.9s  Saved new best backbone (loss 40.0477)
# Epoch 99/3000 — Loss: 40.0449 — Val Acc: 0.9084 — Time: 17.7s  Saved new best backbone (loss 40.0449)
# Epoch 100/3000 — Loss: 40.0245 — Val Acc: 0.8938 — Time: 17.2s  Saved new best backbone (loss 40.0245)
# Epoch 101/3000 — Loss: 40.0450 — Val Acc: 0.8974 — Time: 18.1s
# Epoch 102/3000 — Loss: 40.0013 — Val Acc: 0.8864 — Time: 17.5s  Saved new best backbone (loss 40.0013)
# Epoch 103/3000 — Loss: 39.9919 — Val Acc: 0.8901 — Time: 16.7s  Saved new best backbone (loss 39.9919)
# Epoch 104/3000 — Loss: 39.9095 — Val Acc: 0.8938 — Time: 18.1s  Saved new best backbone (loss 39.9095)
# Epoch 105/3000 — Loss: 39.8926 — Val Acc: 0.8901 — Time: 16.5s  Saved new best backbone (loss 39.8926)
# Epoch 106/3000 — Loss: 39.9309 — Val Acc: 0.8828 — Time: 17.4s
# Epoch 107/3000 — Loss: 39.9631 — Val Acc: 0.9011 — Time: 16.2s
# Epoch 108/3000 — Loss: 39.9455 — Val Acc: 0.8938 — Time: 17.3s
# Epoch 109/3000 — Loss: 39.8800 — Val Acc: 0.8901 — Time: 17.4s  Saved new best backbone (loss 39.8800)
# Epoch 110/3000 — Loss: 39.8925 — Val Acc: 0.8645 — Time: 17.1s
# Epoch 111/3000 — Loss: 39.8035 — Val Acc: 0.8828 — Time: 17.4s  Saved new best backbone (loss 39.8035)
# Epoch 112/3000 — Loss: 39.8414 — Val Acc: 0.9048 — Time: 17.8s
# Epoch 113/3000 — Loss: 39.7935 — Val Acc: 0.8938 — Time: 17.4s  Saved new best backbone (loss 39.7935)
# Epoch 114/3000 — Loss: 39.7249 — Val Acc: 0.8864 — Time: 16.9s  Saved new best backbone (loss 39.7249)
# Epoch 115/3000 — Loss: 39.7425 — Val Acc: 0.8938 — Time: 17.4s
# Epoch 116/3000 — Loss: 39.7483 — Val Acc: 0.9011 — Time: 17.3s
# Epoch 117/3000 — Loss: 39.7315 — Val Acc: 0.8901 — Time: 16.1s
# Epoch 118/3000 — Loss: 39.6899 — Val Acc: 0.8938 — Time: 17.2s  Saved new best backbone (loss 39.6899)
# Epoch 119/3000 — Loss: 39.7094 — Val Acc: 0.8938 — Time: 18.2s
# Epoch 120/3000 — Loss: 39.6578 — Val Acc: 0.8938 — Time: 18.1s  Saved new best backbone (loss 39.6578)
# Epoch 121/3000 — Loss: 39.6708 — Val Acc: 0.8828 — Time: 17.7s
# Epoch 122/3000 — Loss: 39.7078 — Val Acc: 0.8828 — Time: 17.2s
# Epoch 123/3000 — Loss: 39.6673 — Val Acc: 0.8864 — Time: 17.5s
# Epoch 124/3000 — Loss: 39.6007 — Val Acc: 0.8864 — Time: 16.9s  Saved new best backbone (loss 39.6007)
# Epoch 125/3000 — Loss: 39.6279 — Val Acc: 0.8828 — Time: 17.8s
# Epoch 126/3000 — Loss: 39.6179 — Val Acc: 0.9011 — Time: 17.7s
# Epoch 127/3000 — Loss: 39.6136 — Val Acc: 0.8901 — Time: 17.3s
# Epoch 128/3000 — Loss: 39.5722 — Val Acc: 0.8864 — Time: 17.4s  Saved new best backbone (loss 39.5722)
# Epoch 129/3000 — Loss: 39.5587 — Val Acc: 0.8974 — Time: 17.7s  Saved new best backbone (loss 39.5587)
# Epoch 130/3000 — Loss: 39.5844 — Val Acc: 0.9011 — Time: 16.9s
# Epoch 131/3000 — Loss: 39.5136 — Val Acc: 0.8901 — Time: 17.1s  Saved new best backbone (loss 39.5136)
# Epoch 132/3000 — Loss: 39.5351 — Val Acc: 0.8864 — Time: 16.5s
# Epoch 133/3000 — Loss: 39.5375 — Val Acc: 0.9048 — Time: 17.2s
# Epoch 134/3000 — Loss: 39.4750 — Val Acc: 0.9011 — Time: 16.9s  Saved new best backbone (loss 39.4750)
# Epoch 135/3000 — Loss: 39.4610 — Val Acc: 0.9084 — Time: 17.9s  Saved new best backbone (loss 39.4610)
# Epoch 136/3000 — Loss: 39.5388 — Val Acc: 0.8938 — Time: 16.3s
# Epoch 137/3000 — Loss: 39.5128 — Val Acc: 0.9048 — Time: 17.6s
# Epoch 138/3000 — Loss: 39.4988 — Val Acc: 0.8974 — Time: 17.7s
# Epoch 139/3000 — Loss: 39.4507 — Val Acc: 0.8938 — Time: 17.2s  Saved new best backbone (loss 39.4507)
# Epoch 140/3000 — Loss: 39.4478 — Val Acc: 0.8791 — Time: 17.0s  Saved new best backbone (loss 39.4478)
# Epoch 141/3000 — Loss: 39.3768 — Val Acc: 0.8864 — Time: 17.7s  Saved new best backbone (loss 39.3768)
# Epoch 142/3000 — Loss: 39.4052 — Val Acc: 0.8718 — Time: 17.8s
# Epoch 143/3000 — Loss: 39.4301 — Val Acc: 0.9048 — Time: 16.4s
# Epoch 144/3000 — Loss: 39.4125 — Val Acc: 0.8974 — Time: 16.2s
# Epoch 145/3000 — Loss: 39.3833 — Val Acc: 0.8938 — Time: 17.0s
# Epoch 146/3000 — Loss: 39.3906 — Val Acc: 0.8864 — Time: 17.3s
# Epoch 147/3000 — Loss: 39.3633 — Val Acc: 0.8938 — Time: 17.3s  Saved new best backbone (loss 39.3633)
# Epoch 148/3000 — Loss: 39.3599 — Val Acc: 0.8974 — Time: 16.9s  Saved new best backbone (loss 39.3599)
# Epoch 149/3000 — Loss: 39.3272 — Val Acc: 0.8901 — Time: 17.4s  Saved new best backbone (loss 39.3272)
# Epoch 150/3000 — Loss: 39.3610 — Val Acc: 0.8901 — Time: 17.7s
# Epoch 151/3000 — Loss: 39.3275 — Val Acc: 0.8828 — Time: 17.8s
# Epoch 152/3000 — Loss: 39.3474 — Val Acc: 0.8938 — Time: 17.5s
# Epoch 153/3000 — Loss: 39.2439 — Val Acc: 0.9011 — Time: 17.5s  Saved new best backbone (loss 39.2439)
# Epoch 154/3000 — Loss: 39.3308 — Val Acc: 0.8864 — Time: 16.8s
# Epoch 155/3000 — Loss: 39.2330 — Val Acc: 0.9048 — Time: 17.5s  Saved new best backbone (loss 39.2330)
# Epoch 156/3000 — Loss: 39.2523 — Val Acc: 0.8828 — Time: 17.4s
# Epoch 157/3000 — Loss: 39.3063 — Val Acc: 0.9011 — Time: 16.5s
# Epoch 158/3000 — Loss: 39.2762 — Val Acc: 0.9048 — Time: 16.7s
# Epoch 159/3000 — Loss: 39.1977 — Val Acc: 0.8901 — Time: 17.7s  Saved new best backbone (loss 39.1977)
# Epoch 160/3000 — Loss: 39.2006 — Val Acc: 0.9011 — Time: 17.8s
# Epoch 161/3000 — Loss: 39.2310 — Val Acc: 0.9011 — Time: 17.7s
# Epoch 162/3000 — Loss: 39.1678 — Val Acc: 0.8755 — Time: 17.6s  Saved new best backbone (loss 39.1678)
# Epoch 163/3000 — Loss: 39.2186 — Val Acc: 0.9011 — Time: 17.8s
# Epoch 164/3000 — Loss: 39.0888 — Val Acc: 0.9011 — Time: 17.7s  Saved new best backbone (loss 39.0888)
# Epoch 165/3000 — Loss: 39.1661 — Val Acc: 0.8901 — Time: 17.6s
# Epoch 166/3000 — Loss: 39.2135 — Val Acc: 0.8938 — Time: 17.5s
# Epoch 167/3000 — Loss: 39.1598 — Val Acc: 0.8901 — Time: 17.7s
# Epoch 168/3000 — Loss: 39.1130 — Val Acc: 0.8938 — Time: 17.1s
# Epoch 169/3000 — Loss: 39.1817 — Val Acc: 0.8974 — Time: 17.5s
# Epoch 170/3000 — Loss: 39.0681 — Val Acc: 0.8901 — Time: 17.7s  Saved new best backbone (loss 39.0681)
# Epoch 171/3000 — Loss: 39.1270 — Val Acc: 0.8901 — Time: 16.9s
# Epoch 172/3000 — Loss: 39.1149 — Val Acc: 0.8901 — Time: 17.2s
# Epoch 173/3000 — Loss: 39.1653 — Val Acc: 0.8864 — Time: 17.4s
# Epoch 174/3000 — Loss: 39.0366 — Val Acc: 0.8938 — Time: 17.2s  Saved new best backbone (loss 39.0366)
# Epoch 175/3000 — Loss: 39.0358 — Val Acc: 0.8901 — Time: 17.7s  Saved new best backbone (loss 39.0358)
# Epoch 176/3000 — Loss: 39.0852 — Val Acc: 0.8755 — Time: 16.2s
# Epoch 177/3000 — Loss: 39.0342 — Val Acc: 0.8938 — Time: 17.1s  Saved new best backbone (loss 39.0342)
# Epoch 178/3000 — Loss: 39.0192 — Val Acc: 0.9011 — Time: 17.8s  Saved new best backbone (loss 39.0192)
# Epoch 179/3000 — Loss: 39.0459 — Val Acc: 0.9011 — Time: 17.7s
# Epoch 180/3000 — Loss: 38.9870 — Val Acc: 0.9084 — Time: 17.7s  Saved new best backbone (loss 38.9870)
# Epoch 181/3000 — Loss: 39.0317 — Val Acc: 0.8974 — Time: 17.4s
# Epoch 182/3000 — Loss: 38.9819 — Val Acc: 0.9011 — Time: 16.3s  Saved new best backbone (loss 38.9819)
# Epoch 183/3000 — Loss: 39.0477 — Val Acc: 0.9084 — Time: 16.8s
# Early stopping triggered after 183 epochs (no improvement in val_acc for 100 epochs)
# Saved final pretrained encoder to /content/drive/MyDrive/AAVDATASET/models/googlenet_vicreg__lr0.0005_inv25.0_var25.0_cov1.0_e3000_b256_pd256_final.pth
# <ipython-input-6-e18b9179d99f>:260: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   backbone.load_state_dict(torch.load(MODEL_PATH, map_location=DEVICE))
# Feature dimension: 1024
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# KMeans per-class results
#         Correct  Incorrect
# Class
# Double       71         18
# Empty        54          8
# Single       97         26
# Agglomerative per-class results
#         Correct  Incorrect
# Class
# Double        6         83
# Empty        42         20
# Single      102         21
# GMM per-class results
#         Correct  Incorrect
# Class
# Double       71         18
# Empty        54          8
# Single       97         26
